# %%
# import dependencies
import pandas as pd
from datetime import datetime as dt
import time

# %%
# read in csv files

file_path = "Resources/marathon_results_2015.csv"
marathon_2015_df = pd.read_csv(file_path)
marathon_2015_df
# Out:
#        Unnamed: 0    Bib                   Name  Age M/F           City State  \
# 0               0      3         Desisa, Lelisa   25   M           Ambo   NaN
# 1               1      4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN
# 2               2      8         Chebet, Wilson   29   M       Marakwet   NaN
# 3               3     11       Kipyego, Bernard   28   M        Eldoret   NaN
# 4               4     10          Korir, Wesley   32   M         Kitale   NaN
# ...           ...    ...                    ...  ...  ..            ...   ...
# 26593       26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL
# 26594       26594  31359    Emerson, Annette C.   61   F       Old Town    ME
# 26595       26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ
# 26596       26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA
# 26597       26597  25651        Reilly, William   62   M     Kew Garden    NY
#
# ...

# %%
# look at all column labels/names
marathon_2015_df.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
# clean dataframe

# remove any unnecessary columns
marathon_2015_df=marathon_2015_df.drop(labels=["Unnamed: 0", "Citizen", "Unnamed: 9", "Half", "Proj Time", "Overall", "Gender", "Division"], axis=1)
marathon_2015_df
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#             5K      10K      15K      20K      25K      30K      35K      40K  \
# ...

# %%
# By inspecting dataset, it is seen "-" represents a null value

# Remove rows where there is a null value, - 

for index in marathon_2015_df.index:
    
    # check each relavent column. if value is -, then delete entire row.
    
    if marathon_2015_df.loc[index, "5K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "10K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "15K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "20K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "25K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "30K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "35K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "40K"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "Pace"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
    elif marathon_2015_df.loc[index, "Official Time"] == "-":
        marathon_2015_df=marathon_2015_df.drop(index, axis=0)
        
marathon_2015_df
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#             5K      10K      15K      20K      25K      30K      35K      40K  \
# ...

# %%
# check dataframe data types
marathon_2015_df.dtypes
# Out:
# Bib              object
# Name             object
# Age               int64
# M/F              object
# City             object
# State            object
# Country          object
# 5K               object
# 10K              object
# 15K              object
# 20K              object
# 25K              object
# 30K              object
# 35K              object
# 40K              object
# Pace             object
# Official Time    object
# dtype: object

# %%
# function to convert columns from string to datetime

def to_time(df_col):
    # for each item in the column, append yymmdd, to string, then convert to datetime
    time_df_col=[]
    yymmdd='04/20/15'
    for item in df_col:
        # add the yymmdd to the hhmmss string
        full_date=f"{yymmdd} {item}"
        
        # convert to datetime, then append to the time_df_col
        time_df_col.append(datetime.strptime(full_date, '%m/%d/%y %H:%M:%S'))
        
    # return the converted column
    return time_df_col
# Out:
# '00:14:43'

# %%
# convert columns to datetime
marathon_2015_df["5K"]=to_time(marathon_2015_df["5K"])
marathon_2015_df["5K"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20608/2812403978.py in <module>
# ----> 1 marathon_2015_df["5K"]=to_time(marathon_2015_df["5K"])
#       2 marathon_2015_df["5K"]
#
# ~\AppData\Local\Temp/ipykernel_20608/287265696.py in to_time(df_col)
#      10
#      11         # convert to datetime, then append to the time_df_col
# ---> 12         time_df_col.append(datetime.strptime(full_date, '%m/%d/%y %H:%M:%S'))
#      13
#      14     # return the converted column
#
# ~\anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ...

# %%
marathon_2015_df["5K"]
# Out:
# 0       2015-04-20 00:14:43
# 1       2015-04-20 00:14:43
# 2       2015-04-20 00:14:43
# 3       2015-04-20 00:14:43
# 4       2015-04-20 00:14:43
#                 ...
# 26593   2015-04-20 00:50:15
# 26594   2015-04-20 00:48:36
# 26595   2015-04-20 00:53:03
# 26596   2015-04-20 00:49:04
# 26597   2015-04-20 00:40:14
# Name: 5K, Length: 26305, dtype: datetime64[ns]

# %%
marathon_2015_df["5K"][1] - marathon_2015_df["5K"][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20608/3972497720.py in <module>
# ----> 1 marathon_2015_df["5K"][1] - marathon_2015_df["5K"][1]
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
from datetime import datetime

datetime_str = '09/19/18 13:55:26'

datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')

print(type(datetime_object))
print(datetime_object)  # printed in default format
# Out:
# <class 'datetime.datetime'>
# 2018-09-19 13:55:26

# %%
# Out:
# str
