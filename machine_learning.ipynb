# %% [markdown]
# ### Instructions for setting up SQL things:
#
# 1. In pgAdmin/SQL, create a database named "bonkers"
# 2. In the bonkers folder, create a text file, name it config.py
# 3. In config.py, create a variable db_password = "your pgadmin password". Add the config.py file to git ignore.
# 4. To import from SQL -> Jupyter notebook:
#     a. import dependencies.
#     b. create the database engine.
#     c. make a query to select the table you want.
#     d. make a dataframe using: pd.read_sql_query(query_from_4.c, con=enginer_from_4.b
# 5. To export from Jupyter notebook -> SQL:
#     a. import dependencies.
#     b. create engine.
#     c. export the dataframe using: df.to_sql(name="table name", con=engine_from_5.b)

# %%
# import data from SQL to use for machine learning model

# %%
# import dependency
import pandas as pd

from sqlalchemy import create_engine
from config import db_password

# %%
# make connection string for database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/bonkers"

# create the database engine
engine = create_engine(db_string)

# %%
# create a query to select all rows from the table we want to make a dataframe for
query="SELECT * FROM marathon_2015_paces"

# make the datafram for the table
data = pd.read_sql_query(query, con=engine)
data
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo  None     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa  None     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet  None     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret  None     KEN
# 4         10          Korir, Wesley   32   M         Kitale  None     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26299  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26300  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26301  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26302  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26303  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#        Pace (0-5K)  Pace (5-10K)  Pace (10-15K)  Pace (15-20K)  Pace (20-25K)  \
# ...
